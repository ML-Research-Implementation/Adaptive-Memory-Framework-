# %% [markdown]
# # AMMR Phase 5 Execution
# Welcome to Google Colab! This free environment gives you access to a T4 GPU and ~12GB of RAM to run the full Adaptive Memory Retention experiment.
#
# ### Step 1: Upload your code
# Upload the `ammr_project.zip` file to this Colab session using the folder icon on the left sidebar.
#
# ### Step 2: Run the cells below

# %%
# !unzip -q ammr_project.zip -d ammr_project

# %%
# %cd ammr_project
# !pip install -r requirements.txt -q
# !pip install datasets transformers scikit-learn -q

# %% [markdown]
# ### Step 3: Train the Models and Generate the Pareto Curve
# The following cell will execute Phase 5. It will train the Baseline, QA Only, Logit KD, and Full KD models, and then evaluate them.

# %%
# !python run_ablations.py
